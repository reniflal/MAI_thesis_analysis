# %%
import json
import matplotlib.pyplot as plt
# Specify the file name
file_name = 'eye_data_for_graph.json'

# Load the dictionary from the file
with open(file_name, 'r') as file:
    eye_data_for_graph = json.load(file)

# Specify the file name
file_name = 'eeg_data_for_graph.json'

# Load the dictionary from the file
with open(file_name, 'r') as file:
    eeg_data_for_graph = json.load(file)
    
    
# Plotting the line chart
plt.figure(figsize=(12, 8))
plt.plot(eeg_data_for_graph["Dwelltime"], eeg_data_for_graph["count_true_positive"], marker='s', linestyle='-', color='r', label='eeg_plus_dwelltime')
plt.plot(eye_data_for_graph["Dwelltime"], eye_data_for_graph["count_true_positive"], marker='o', linestyle='-', color='b', label='simple_dwelltime')

# Adding titles and labels
plt.title('Simple Dwelltime paradigm Vs Dwelltime+BCI paradigm - True Positive', fontsize=16)
plt.xlabel('Dwelltime', fontsize=14)
plt.ylabel('Percentage', fontsize=14)
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

# Displaying the chart
plt.show()


# Plotting the line chart
plt.figure(figsize=(12, 8))
plt.plot(eeg_data_for_graph["Dwelltime"], eeg_data_for_graph["count_true_negative"], marker='s', linestyle='-', color='r', label='eeg_plus_dwelltime')
plt.plot(eye_data_for_graph["Dwelltime"], eye_data_for_graph["count_true_negative"], marker='o', linestyle='-', color='b', label='simple_dwelltime')

# Adding titles and labels
plt.title('Simple Dwelltime paradigm Vs Dwelltime+BCI paradigm - True Negative', fontsize=16)
plt.xlabel('Dwelltime', fontsize=14)
plt.ylabel('Percentage', fontsize=14)
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

# Displaying the chart
plt.show()

# %%
import json
import matplotlib.pyplot as plt
# Specify the file name
file_name = 'eye_data_for_graph1.json'

# Load the dictionary from the file
with open(file_name, 'r') as file:
    eye_data_for_graph1 = json.load(file)
    
# Specify the file name
file_name = 'eye_data_for_graph2.json'

# Load the dictionary from the file
with open(file_name, 'r') as file:
    eye_data_for_graph2 = json.load(file)

# Specify the file name
file_name = 'eeg_data_for_graph1.json'

# Load the dictionary from the file
with open(file_name, 'r') as file:
    eeg_data_for_graph1 = json.load(file)

# Specify the file name
file_name = 'eeg_data_for_graph2.json'

# Load the dictionary from the file
with open(file_name, 'r') as file:
    eeg_data_for_graph2 = json.load(file)
    
# Plotting the line chart
plt.figure(figsize=(12, 8))
plt.plot(eeg_data_for_graph1["Dwelltime"], eeg_data_for_graph1["count_true_positive"], marker='s', linestyle='-', color='r', label='eeg_plus_dwelltime_exp1')
plt.plot(eye_data_for_graph1["Dwelltime"], eye_data_for_graph1["count_true_positive"], marker='o', linestyle='-', color='b', label='simple_dwelltime_exp1')
plt.plot(eeg_data_for_graph2["Dwelltime"], eeg_data_for_graph2["count_true_positive"], marker='s', linestyle='-', color='m', label='eeg_plus_dwelltime_exp2')
plt.plot(eye_data_for_graph2["Dwelltime"], eye_data_for_graph2["count_true_positive"], marker='o', linestyle='-', color='c', label='simple_dwelltime_exp2')
# Adding titles and labels
plt.title('Simple Dwelltime paradigm Vs Dwelltime+BCI paradigm - True Positive', fontsize=16)
plt.xlabel('Dwelltime', fontsize=14)
plt.ylabel('Percentage', fontsize=14)
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

# Displaying the chart
plt.show()


# Plotting the line chart
plt.figure(figsize=(12, 8))
plt.plot(eeg_data_for_graph1["Dwelltime"], eeg_data_for_graph1["count_true_negative"], marker='s', linestyle='-', color='r', label='eeg_plus_dwelltime_exp1')
plt.plot(eye_data_for_graph1["Dwelltime"], eye_data_for_graph1["count_true_negative"], marker='o', linestyle='-', color='b', label='simple_dwelltime_exp1')
plt.plot(eeg_data_for_graph2["Dwelltime"], eeg_data_for_graph2["count_true_negative"], marker='s', linestyle='-', color='m', label='eeg_plus_dwelltime_exp2')
plt.plot(eye_data_for_graph2["Dwelltime"], eye_data_for_graph2["count_true_negative"], marker='o', linestyle='-', color='c', label='simple_dwelltime_exp2')
# Adding titles and labels
plt.title('Simple Dwelltime paradigm Vs Dwelltime+BCI paradigm - True Negative', fontsize=16)
plt.xlabel('Dwelltime', fontsize=14)
plt.ylabel('Percentage', fontsize=14)
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

# Displaying the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 7
#       4 file_name = 'eye_data_for_graph1.json'
#       6 # Load the dictionary from the file
# ----> 7 with open(file_name, 'r') as file:
#       8     eye_data_for_graph1 = json.load(file)
#      10 # Specify the file name
#
# File ~/opt/anaconda3/envs/psychopy_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'eye_data_for_graph1.json'
